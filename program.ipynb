# %%
import sys

for i in range(1,10):
    if i==9:
        sys.exit()
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\HP 850G2\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import random

for i in range(5):
    print(random.randint(0,1))
# Out:
# 0
# 1
# 0
# 0
# 0

# %%
import random

print("Let's Play Guessing Game!!!!")

print('Range 1 to 20')

actual_number = random.randint(1,20)
print("You have only 5 chance")
user_guess = int(input("Take a guess: "))
guess = 0
for i in range(1,6):
    user_guess = int(input("Take a guess: "))
    if user_guess < actual_number:
        print('Your guess too low')
    
    elif user_guess > actual_number:
        print('Your guess too high')

    else:
        print("Great You Guess the number")
        guess = 1
        break
if guess == 0:
    print('Next Time')
# Out:
# Let's Play Guessing Game!!!!
# Range 1 to 20
# You have only 5 chance
# Your guess too low
# Your guess too low
# Your guess too low
# Your guess too low
# Your guess too high
# Next Time

# %%
#Rock Paper Scissors
import random

print("ROCK PAPER SCISSOR Game")

wins = 0
loss = 0
tie = 0

while True:
    print("%s Wins, %s Loss, %s Ties" % (wins, loss, tie))

    #Player Choose

    player = input('Choose one of the (r)ock, (p)aper, (s)cissor and (q)uit: ')

    if player!='r' and player!='p' and player!='s' and player!='q':
        print("Choose r, p, s, q")
        continue
    
    if player=='r':
        print("Rock Vs", end=" ")
    elif player=='s':
        print("Scissor Vs", end=" ")
    elif player=='p':
        print("Paper Vs", end=" ")
    elif player=='q':
        print("Quit")
        break

    #Computer Choose

    computer = random.randint(1,3)

    if computer==1:
        computer='r'
        print("Rock")
    elif computer==2:
        computer='s'
        print("Scissor")
    elif computer==3:
        computer='p'
        print("paper")

    #check

    if player=='r' and computer=='s':
        print("You win")
        wins = wins + 1
    elif player=='s' and computer=='p':
        print("You win")
        wins = wins + 1
    elif player=='p' and computer=='r':
        print("You win")
        wins = wins + 1
    elif player==computer:
        print("Tie")
        tie = tie + 1
    elif player=='s' and computer=='r':
        print("You Loss")
        loss = loss + 1
    elif player=='p' and computer=='s':
        print("You Loss")
        loss = loss + 1
    elif player=='r' and computer=='p':
        print("You Loss")
        loss = loss + 1
# Out:
# ROCK PAPER SCISSOR Game
# 0 Wins, 0 Loss, 0 Ties
# Rock Vs Scissor
# You win
# 1 Wins, 0 Loss, 0 Ties
# Paper Vs paper
# Tie
# 1 Wins, 0 Loss, 1 Ties
# Rock Vs paper
# You Loss
# 1 Wins, 1 Loss, 1 Ties
# Scissor Vs Rock
# You Loss
# 1 Wins, 2 Loss, 1 Ties
# Paper Vs Rock
# You win
# 2 Wins, 2 Loss, 1 Ties
# Quit

# %%
def a():
    print('a() starts')
    b()
    d()
    print('a() returns')

def b():
    print('b() starts')
    c()
    print('b() returns')

def c():
    print('c() starts')
    print('c() returns')

def d():
    print('d() starts')
    print('d() returns')

a()
# Out:
# a() starts
# b() starts
# c() starts
# c() returns
# b() returns
# d() starts
# d() returns
# a() returns

# %%
def collatz(number):
    if number % 2 == 0:
        even = number // 2
        
        return even
    elif number % 2 == 1:
        odd = 3 * number + 1
        
        return odd

user  = int(input("Enter Number: "))
result = collatz(user)
print(result)
if result!=1:
    while True:

        result = collatz(result)

        print(result)

        if result==1:
            break
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
list_1 = [1,2,3,4] + [5,6,7,8]

print(list_1)

list_2 = ["x","y","z"] * 3

print(list_2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# ['x', 'y', 'z', 'x', 'y', 'z', 'x', 'y', 'z']

# %%
supplies = ['pens', 'staplers', 'flamethrowers', 'binders']

for i in range(len(supplies)):

    print('Index ' + str(i) + ' in supplies is: ' + supplies[i])
# Out:
# Index 0 in supplies is: pens
# Index 1 in supplies is: staplers
# Index 2 in supplies is: flamethrowers
# Index 3 in supplies is: binders

# %%
supplies = ['pens', 'staplers', 'flamethrowers', 'binders']

for index, value in enumerate(supplies):

    print('Index ' + str(index) + ' in supplies is: ' + value)

cat = ['fat', 'gray', 'loud']
size, color, disposition = cat
# Out:
# Index 0 in supplies is: pens
# Index 1 in supplies is: staplers
# Index 2 in supplies is: flamethrowers
# Index 3 in supplies is: binders

# %%
import random

lis = [1,2,5,4]
random.shuffle(lis)
print(lis)

lis.sort(reverse=True)
print(lis)
# Out:
# [1, 4, 2, 5]
# [5, 4, 2, 1]

# %%
# Conway's Game of Life
import random, time, copy
WIDTH = 60
HEIGHT = 20

# Create a list of list for the cells:
nextCells = []
for x in range(WIDTH):
    column = [] # Create a new column.
    for y in range(HEIGHT):
        if random.randint(0, 1) == 0:
            column.append('#') # Add a living cell.
        else:
            column.append(' ') # Add a dead cell.
    nextCells.append(column) # nextCells is a list of column lists.

while True: # Main program loop.
    print('\n\n\n\n\n') # Separate each step with newlines.
    currentCells = copy.deepcopy(nextCells)

    # Print currentCells on the screen:
    for y in range(HEIGHT):
        for x in range(WIDTH):
            print(currentCells[x][y], end='') # Print the # or space.
        print() # Print a newline at the end of the row.

    # Calculate the next step's cells based on current step's cells:
    for x in range(WIDTH):
        for y in range(HEIGHT):
            # Get neighboring coordinates:
            # `% WIDTH` ensures leftCoord is always between 0 and WIDTH - 1
            leftCoord  = (x - 1) % WIDTH
            rightCoord = (x + 1) % WIDTH
            aboveCoord = (y - 1) % HEIGHT
            belowCoord = (y + 1) % HEIGHT

            # Count number of living neighbors:
            numNeighbors = 0
            if currentCells[leftCoord][aboveCoord] == '#':
                numNeighbors += 1 # Top-left neighbor is alive.
            if currentCells[x][aboveCoord] == '#':
                numNeighbors += 1 # Top neighbor is alive.
            if currentCells[rightCoord][aboveCoord] == '#':
                numNeighbors += 1 # Top-right neighbor is alive.
            if currentCells[leftCoord][y] == '#':
                numNeighbors += 1 # Left neighbor is alive.
            if currentCells[rightCoord][y] == '#':
                numNeighbors += 1 # Right neighbor is alive.
            if currentCells[leftCoord][belowCoord] == '#':
                numNeighbors += 1 # Bottom-left neighbor is alive.
            if currentCells[x][belowCoord] == '#':
                numNeighbors += 1 # Bottom neighbor is alive.
            if currentCells[rightCoord][belowCoord] == '#':
                numNeighbors += 1 # Bottom-right neighbor is alive.

            # Set cell based on Conway's Game of Life rules:
            if currentCells[x][y] == '#' and (numNeighbors == 2 or numNeighbors == 3):
                # Living cells with 2 or 3 neighbors stay alive:
                nextCells[x][y] = '#'
            elif currentCells[x][y] == ' ' and numNeighbors == 3:
                # Dead cells with 3 neighbors become alive:
                nextCells[x][y] = '#'
            else:
                # Everything else dies or stays dead:
                nextCells[x][y] = ' '
    time.sleep(1) # Add a 1-second pause to reduce flickering.
# Out:
# # # ####   ##     ##### ##    #  #   #  ## #   # # ##   ####
#  # #    #### # ## # ####  # ## ## #######   ###  # #  # #
# ## ## #  # ###### # # # # ## # ####### #   # #  ##### #   ##
# ### ## #### ##    # ###  #   #   ## ##   ##  # ##  ##### ##
#  #######   # #  # ###   # ### #  #    #   ##  #   #  #  ###
#  ##  ##     ##   ###### # ## ##### ### #########   # # #   #
#  # # # #      ## #  ###  #       ## ### # #   ###    #  ####
#   ## # ##      # # ####   # #  ##   #### ## ###    ## # #
# ##  ## # #  # # #  #   ##    ## ###   ## #  #   ###  # # ###
#    #     #### # ## #    # #  # ## #  #  #  #   ###### ## #
#  ## #  ##### #### #         #####  # #  ## ### ##### ##  # #
#   #  ### ###   # # ###    #  ## ##   # # ####     # #      #
#         ####   ####       ### # #   ## # ##  ## # #  ######
#  # ### #  # # #####  ## ###        # #  # ## ######  #   # #
#  ###  # #####     # ## ############  # ## ###   ## #  ##  ##
#   #   # #  #  #  # ##        ###    #  ## # # ## ## ##  #
# ...

# %%
#Comma Code

def list_to_string(sequence):
    string = ''
    length = len(sequence)
    if length > 1:
        for i in range(length):
            if i == (length - 1):
                string += " and" 
                string += " " + sequence[i]
                break    
            string += " " + sequence[i] + ","
    else:
        return "List must have more then 1 element"
    return string

spam = ['apples', 'bananas', 'tofu', 'cats']

result = list_to_string(spam)
print(result)
# Out:
#  apples, bananas, tofu, and cats

# %%
import random
numberOfStreaks = 0

def count_fun(check, coin_list):
    count = 0
    for i in range(len(coin_list)):
        if coin_list[i] == check:
            count += 1
            if count == 6:
                count = 0
                return True  # Reset the count to prevent overlapping streaks
        else:
            count = 0  # Reset the count if the sequence breaks
    return False
for experimentNumber in range(10000):
    coin_list = []
    
    # Code that creates a list of 100 'heads' or 'tails' values.
    for i in range(100):
        chose = random.randint(0,1)
        if chose == 0:
            coin_list.append("T")
        else:
            coin_list.append("H")
    

    # Code that checks if there is a streak of 6 heads or tails in a row.
    if count_fun("H", coin_list) or count_fun("T", coin_list):
        numberOfStreaks+=1

print('Chance of streak: %s%%' % (numberOfStreaks / 100))
# Out:
# Chance of streak: 80.54%

# %%
grid = [['.', '.', '.', '.', '.', '.'],
        ['.', 'O', 'O', '.', '.', '.'],
        ['O', 'O', 'O', 'O', '.', '.'],
        ['O', 'O', 'O', 'O', 'O', '.'],
        ['.', 'O', 'O', 'O', 'O', 'O'],
        ['O', 'O', 'O', 'O', 'O', '.'],
        ['O', 'O', 'O', 'O', '.', '.'],
        ['.', 'O', 'O', '.', '.', '.'],
        ['.', '.', '.', '.', '.', '.']]

for i in range(6):
    for j in range(9):
        print(grid[j][i], end="")
    print()
# Out:
# ..OO.OO..
# .OOOOOOO.
# .OOOOOOO.
# ..OOOOO..
# ...OOO...
# ....O....

# %%
def isValidChessBoard(chess_board):
    piece_name = ['wpawn', 'wknight', 'wbishop','wrook','wqueen','wking',
                  'bpawn', 'bknight', 'bbishop','brook','bqueen','bking']
    
    alphabet = ['a','b','c','d','e','f','g','h']

    black = 0
    white = 0
    black_k = 0
    white_k = 0
    bpawn = 0
    wpawn = 0
    for key, value in chess_board.items():
        if value not in piece_name:
            return False
        elif (int(key[0]) > 8) or (key[1] not in alphabet):
            return False
        if value[0] == 'b':
            black += 1
        elif value[0] == 'w':
            white += 1
        if black > 16 or white > 16:
            return False
        if value == 'bking':
            black_k += 1
        elif value == 'wking':
            white_k += 1
        elif value=='bpawn':
            bpawn += 1
        elif value=='wpawn':
            wpawn += 1
        if bpawn > 8 or wpawn > 8:
            return False
        
    if black_k != 1 or white_k != 1:
            return False
    return True

chess_board = {'1h': 'bking', '6c': 'wqueen', '2g': 'bbishop', '5h': 'bqueen', '3e': 'wking'}

if isValidChessBoard(chess_board):
    print("Valid")

else:
    print('Invalid')
# Out:
# Valid

# %%
# inventory.py
stuff = {'rope': 1, 'torch': 6, 'gold coin': 42, 'dagger': 1, 'arrow': 12}

def displayInventory(inventory):
    print("Inventory:")
    item_total = 0
    for k, v in inventory.items():
        item_total += v
        print(str(v)+" "+k)
    print("Total number of items: " + str(item_total))

displayInventory(stuff)
# Out:
# Inventory:
# 1 rope
# 6 torch
# 42 gold coin
# 1 dagger
# 12 arrow
# Total number of items: 62

# %%
def displayInventory(inventory):
    print("Inventory:")
    item_total = 0
    for k, v in inventory.items():
        item_total += v
        print(str(v)+" "+k)
    print("Total number of items: " + str(item_total))


def addToInventory(inventory, addedItems):
    # your code goes here
    for i in addedItems:
        if i in inventory:
            inventory[i] +=1
        else:
            inventory[i] = 1
    return inventory

inv = {'gold coin': 42, 'rope': 1}
dragonLoot = ['gold coin', 'dagger', 'gold coin', 'gold coin', 'ruby','ruby']
inv = addToInventory(inv, dragonLoot)

displayInventory(inv)
# Out:
# Inventory:
# 45 gold coin
# 1 rope
# 1 dagger
# 2 ruby
# Total number of items: 49

# %%
import pyperclip
pyperclip.copy("The pyperclip module does not come with Python. To install it, follow the directions for installing third-party modules in Appendix ")
pyperclip.paste()
# Out:
# 'The pyperclip module does not come with Python. To install it, follow the directions for installing third-party modules in Appendix '
